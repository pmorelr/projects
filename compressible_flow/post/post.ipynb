# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %%
ex1 = pd.read_csv (r'ex1_1.csv')
ex1_x = np.array(ex1)[:,0]
ex1_y = np.array(ex1)[:,1]

ex1x = pd.read_csv (r'ex1_1ex.csv')
ex1x_x = np.array(ex1x)[:,0]
ex1x_y = np.array(ex1x)[:,1]

ex2= pd.read_csv (r'ex1_2.csv')
ex2_x = np.array(ex2)[:,0]
ex2_y = np.array(ex2)[:,1]

ex2x = pd.read_csv (r'ex1_2ex.csv')
ex2x_x = np.array(ex2x)[:,0]
ex2x_y = np.array(ex2x)[:,1]

ex3 = pd.read_csv (r'ex1_3.csv')
ex3_x = np.array(ex3)[:,0]
ex3_y = np.array(ex3)[:,1]

ex3x = pd.read_csv (r'ex1_3ex.csv')
ex3x_x = np.array(ex3x)[:,0]
ex3x_y = np.array(ex3x)[:,1]

# %%
rus200h = pd.read_csv(r'1rusanov_height200.csv')
rus200h_x = np.array(rus200h)[:,0]
rus200h_y = np.array(rus200h)[:,1]

rus200v = pd.read_csv (r'1rusanov_velocity200.csv')
rus200v_x = np.array(rus200v)[:,0]
rus200v_y = np.array(rus200v)[:,1]

rus200m= pd.read_csv(r'1rusanov_momentum200.csv')
rus200m_x = np.array(rus200m)[:,0]
rus200m_y = np.array(rus200m)[:,1]

roe200h = pd.read_csv (r'1roe_height200.csv')
roe200h_x = np.array(roe200h)[:,0]
roe200h_y = np.array(roe200h)[:,1]

roe200v = pd.read_csv(r'1roe_velocity200.csv')
roe200v_x = np.array(roe200v)[:,0]
roe200v_y = np.array(roe200v)[:,1]

roe200m= pd.read_csv (r'1roe_momentum200.csv')
roe200m_x = np.array(roe200m)[:,0]
roe200m_y = np.array(roe200m)[:,1]

# %%
ex_h = pd.read_csv(r'1exact_height.csv')
ex_h_x = np.array(ex_h)[:,0]
ex_h_y = np.array(ex_h)[:,1]

ex_v = pd.read_csv (r'1exact_velocity.csv')
ex_v_x = np.array(ex_v)[:,0]
ex_v_y = np.array(ex_v)[:,1]

ex_m = pd.read_csv (r'1exact_momentum.csv')
ex_m_x = np.array(ex_m)[:,0]
ex_m_y = np.array(ex_m)[:,1]

# %%
plt.figure(dpi=400)
plt.plot(ex_h_x, ex_h_y, 'k-.', mfc='none', linewidth=1, label = "Exact solution")
plt.plot(rus200h_x, rus200h_y, 'r.', markersize=1.4, label = "Rusanov's method")
plt.plot(roe200h_x, roe200h_y, 'b.', markersize=1.6, label = "Roe's method")
plt.title("Height at t = 1.2, Nc = 200")
plt.ylabel('Height')
plt.legend()
plt.savefig('1height')

# %%
plt.figure(dpi=400)
plt.plot(ex_v_x, ex_v_y, 'k-.', mfc='none', linewidth=1, label = "Exact solution")
plt.plot(rus200v_x, rus200v_y, 'r.', markersize=1.4, label = "Rusanov's method")
plt.plot(roe200v_x, roe200v_y, 'b.', markersize=1.6, label = "Roe's method")
plt.title("Velocity at t = 1.2, Nc = 200")
plt.ylabel('Velocity')
plt.legend()
plt.savefig('1velocity')

# %%
plt.figure(dpi=400)
plt.plot(ex_m_x, ex_m_y, 'k-.', mfc='none', linewidth=1, label = "Exact solution")
plt.plot(rus200m_x, rus200m_y, 'r.', markersize=1.4, label = "Rusanov's method")
plt.plot(roe200m_x, roe200m_y, 'b.', markersize=1.6, label = "Roe's method")
plt.title("Momentum at t = 1.2, Nc = 200")
plt.ylabel('Momentum')
plt.legend()
plt.savefig('1momentum')

# %%
rus1000h = pd.read_csv(r'1rusanov_height1000.csv')
rus1000h_x = np.array(rus1000h)[:,0]
rus1000h_y = np.array(rus1000h)[:,1]

rus1000v = pd.read_csv (r'1rusanov_velocity1000.csv')
rus1000v_x = np.array(rus1000v)[:,0]
rus1000v_y = np.array(rus1000v)[:,1]

rus1000m= pd.read_csv(r'1rusanov_momentum1000.csv')
rus1000m_x = np.array(rus1000m)[:,0]
rus1000m_y = np.array(rus1000m)[:,1]

roe1000h = pd.read_csv (r'1roe_height1000.csv')
roe1000h_x = np.array(roe1000h)[:,0]
roe1000h_y = np.array(roe1000h)[:,1]

roe1000v = pd.read_csv(r'1roe_velocity1000.csv')
roe1000v_x = np.array(roe1000v)[:,0]
roe1000v_y = np.array(roe1000v)[:,1]

roe1000m= pd.read_csv (r'1roe_momentum1000.csv')
roe1000m_x = np.array(roe1000m)[:,0]
roe1000m_y = np.array(roe1000m)[:,1]

# %%
plt.figure(dpi=400)
plt.plot(ex_h_x, ex_h_y, 'k-', mfc='none', linewidth=1.8, label = "Exact solution")
plt.plot(rus1000h_x, rus1000h_y, '-', color = 'purple', linewidth=1.5, label = "Rusanov's method")
plt.plot(roe1000h_x, roe1000h_y, '-.', color = 'orange',linewidth=1, label = "Roe's method")
plt.title("Height at t = 1.2, Nc = 1000")
plt.ylabel('Height')
plt.legend()
plt.savefig('2height')

# %%
plt.figure(dpi=400)
plt.plot(ex_v_x, ex_v_y, 'k-', mfc='none', linewidth=1.8, label = "Exact solution")
plt.plot(rus1000v_x, rus1000v_y, '-', color='purple', linewidth=1.5, label = "Rusanov's method")
plt.plot(roe1000v_x, roe1000v_y, '-.',color='orange',linewidth=1, label = "Roe's method")
plt.title("Velocity at t = 1.2, Nc = 1000")
plt.ylabel('Velocity')
plt.legend()
plt.savefig('2velocity')

# %%
plt.figure(dpi=400)
plt.plot(ex_m_x, ex_m_y, 'k-', mfc='none', linewidth=1.8, label = "Exact solution")
plt.plot(rus1000m_x, rus1000m_y, '-', color='purple', linewidth=1.5, label = "Rusanov's method")
plt.plot(roe1000m_x, roe1000m_y, '-.',color='orange',linewidth=1, label = "Roe's method")
plt.title("Momentum at t = 1.2, Nc = 1000")
plt.ylabel('Momentum')
plt.legend()
plt.savefig('2momentum')

# %%
plt.figure(dpi=400)
plt.plot(ex1x_x, ex1x_y, 'b-.', linewidth=1.2, label = "Exact solution")
plt.plot(ex1_x, ex1_y, 'k.', mfc='none', markersize=1.6, label = "Computed solution")
plt.title("Height at t = 1.2, Nc = 200")
plt.ylabel('Height')
plt.legend()
plt.savefig('height_rusanov')

# %%
plt.figure(dpi=400)
plt.plot(ex2x_x, ex2x_y, 'b-.', linewidth=1.2, label = "Exact solution")
plt.plot(ex2_x, ex2_y, 'k.', mfc='none', markersize=1.6, label = "Computed solution")
plt.title("Velocity at t = 1.2, Nc = 200")
plt.ylabel('Velocity')
plt.legend()
plt.savefig('velocity_rusanov')

# %%
plt.figure(dpi=400)
plt.plot(ex3x_x, ex3x_y, 'b-.', linewidth=1.2, label = "Exact solution")
plt.plot(ex3_x, ex3_y, 'k.', mfc='none', markersize=1.6, label = "Computed solution")
plt.title("Momentum at t = 1.2, Nc = 200")
plt.ylabel('Momentum')
plt.legend()
plt.savefig('momentum_rusanov')

# %%
bot= pd.read_csv (r'bottom.csv')
bot_x = np.array(bot)[:,0]
bot_y = np.array(bot)[:,1]

h01= pd.read_csv (r'h01.csv')
h01_x = np.array(h01)[:,0]
h01_y = np.array(h01)[:,1]

h04= pd.read_csv (r'h04.csv')
h04_x = np.array(h04)[:,0]
h04_y = np.array(h04)[:,1]

h07= pd.read_csv (r'h07.csv')
h07_x = np.array(h07)[:,0]
h07_y = np.array(h07)[:,1]

h20= pd.read_csv (r'h20.csv')
h20_x = np.array(h20)[:,0]
h20_y = np.array(h20)[:,1]

h1000= pd.read_csv (r'h1000.csv')
h1000_x = np.array(h1000)[:,0]
h1000_y = np.array(h1000)[:,1]

u01= pd.read_csv (r'u01.csv')
u01_x = np.array(u01)[:,0]
u01_y = np.array(u01)[:,1]

u04= pd.read_csv (r'u04.csv')
u04_x = np.array(u04)[:,0]
u04_y = np.array(u04)[:,1]

u07= pd.read_csv (r'u07.csv')
u07_x = np.array(u07)[:,0]
u07_y = np.array(u07)[:,1]

u20= pd.read_csv (r'u20.csv')
u20_x = np.array(u20)[:,0]
u20_y = np.array(u20)[:,1]

u1000= pd.read_csv (r'u1000.csv')
u1000_x = np.array(u1000)[:,0]
u1000_y = np.array(u1000)[:,1]

# %%
plt.figure(dpi=400)
plt.plot(u1000_x, u1000_y, '.', markersize=2.0, color = 'darkblue', label = "Computed solution Nc = 1000")
plt.plot(u07_x, u07_y, '.', markersize=2.0, color = 'mediumvioletred', label = "Computed solution Nc = 200")

#plt.plot(bot_x, bot_y, 'k-.', mfc='none',linewidth=1.2, label = "Topography b(x)")
plt.title("Velocity at t = 2.0")
plt.ylabel('Height')
plt.legend()
plt.savefig('u1000')

# %%
plt.figure(dpi=400)
plt.plot(ex1_x, ex1_y, '-.', markersize=1.6, linewidth=1.2,color='purple', label = "Computed solution")
plt.title("Height at t = 0.7, Nc = 200")
plt.ylabel('Height')
plt.legend()
plt.savefig('exercice2_solo')

# %%
plt.figure(dpi=400)
plt.plot(ex3_x, ex3_y, 'g-.', markersize=1.6,linewidth=1.2,,color='purple', label = "Computed solution")
plt.title("Height at t = 0.7, Nc = 200")
plt.ylabel('Height')
plt.legend()
plt.savefig('exercice2_velocity')

# %%
udry= pd.read_csv (r'udry.csv')
udry_x = np.array(udry)[:,0]
udry_y = np.array(udry)[:,1]

hdry= pd.read_csv (r'hdry.csv')
hdry_x = np.array(hdry)[:,0]
hdry_y = np.array(hdry)[:,1]

bdry= pd.read_csv (r'bdry.csv')
bdry_x = np.array(bdry)[:,0]
bdry_y = np.array(bdry)[:,1]

# %%
plt.figure(dpi=400)
plt.plot(hdry_x, hdry_y, '.', markersize=1.8,linewidth=1.2,color='steelblue', label = "Computed solution")
plt.plot(bdry_x, bdry_y, '-.', markersize=1.6,linewidth=1.1,color='black', label = "Topography b(x)")
plt.title("Height at t = 19.8, Nc = 200")
plt.ylabel('Height')
plt.legend()
plt.savefig('hdry')

# %%
plt.figure(dpi=400)
plt.plot(udry_x, udry_y, '.', markersize=1.8,linewidth=1.2,color='steelblue', label = "Computed solution")
#plt.plot(bdry_x, bdry_y, '-.', markersize=1.6,linewidth=1.1,color='black', label = "Topography b(x)")
plt.title("Velocity at t = 19.8, Nc = 200")
plt.ylabel('Velocity')
plt.legend()
plt.savefig('udry')
